# %%
# 1 samples must be a = [state, action, rewards, next_state, is_done]
# is_done is for determining a terminal or non-terminal state

import random
import tensorflow as tf
import numpy as np

class ReplayMemory:
    main_memory = []
    max_reply = 0
    num_batch = 0
    def __init__(self, max_replay: int, mini_batch_num: int):
        self.max_reply = max_replay
        self.num_batch = mini_batch_num

class DeepQAgent:
    replay:ReplayMemory = None
    num_actions: int = None
    eval_model = None
    target_model = None
    gamma:float = None
    epsilon:float = None
    epsilon_min: float = None
    epsilon_decay: float = None
    
    # counter for updating model weight
    learn_counter: int = 0
    update_weight_on: int = 0
    
    def __init__(self, num_actions: int, max_replay: int, mini_batch_num: int, 
                 weight_update: int, epsilon: float, epsilon_min: float, 
                 epsilon_decay:float, gamma:float):
        self.replay = ReplayMemory(max_replay, mini_batch_num)
        self.eval_model, self.target_model = self.create_model()
        self.num_actions = int(num_actions)
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.update_weight_on = weight_update
        
    def create_model(self):
        # Create your own model and return the sequential model.
        # Need to watchout your input is need to be a state shape
        # And your output need to be your action shape
        model = tf.keras.models.Sequential([
            tf.keras.layers.Input(shape=(2,)),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(3, activation='linear'),
        ])
        
        model.compile(optimizer = 'adam',
                      loss = 'mean_squared_error',
                      metrics= ['mse']
                      )
        
        return model, model
        
    def store_memory(self, state, action, rewards, next_state, is_done):
        if len(self.replay.main_memory) == self.replay.max_reply:
            self.replay.main_memory.pop(0)
        self.replay.main_memory.append([state, action, rewards, 
                                        next_state, is_done])
        
    def pick_action(self, state, epsilon = None):
        if epsilon == None:
            epsilon = self.epsilon
        action = None
        if random.random() > epsilon:
            if type(state) != list:
                state = state.tolist()
            prediction = self.eval_model.predict([state])[0]
            action = np.argmax(prediction)
        else:
            action = random.randint(0, self.num_actions - 1)
            
        return action
    
    def learn(self):
        if len(self.replay.main_memory) < self.replay.num_batch:
            return
        samples = self.__sample_mini_batch__()
        X_current = [x[0] for x in samples]
        X_current = np.array(X_current)
        X_next = [x[3] for x in samples]
        X_next = np.array(X_next)
        prediction = self.eval_model.predict(X_current)
        target_prediction = self.target_model.predict(X_next)
        for i in range(len(samples)):
            if samples[i][4]: # if is_done
                # For terminal next state
                prediction[i][samples[i][1]] = samples[i][2]
            else:
                # For non-terminal next state
                target = self.gamma * target_prediction[i][samples[i][1]]
                prediction[i][samples[i][1]] = samples[i][2] + target
                
        X_train = [i[0] for i in samples]
        X_train = np.array(X_train)
        self.eval_model.fit(X_train, prediction, verbose=1, epochs=10)
        if self.learn_counter % self.update_weight_on == 0:
            self.__update_target_models__()
        
        # Post Learn
        self.learn_counter += 1
        epsilon_after_decay = self.epsilon * self.epsilon_decay
        if  epsilon_after_decay < self.epsilon_min:
            self.epsilon = self.epsilon_min
        else:
            self.epsilon = epsilon_after_decay
            
    def load_model(self,path:str):
        self.target_model = tf.keras.models.load_model(path)
        self.eval_model = tf.keras.models.load_model(path)
        print("Model Loaded")
        
    def save_model(self,path:str):
        self.eval_model.save(path)
        print("Model saved")
            
    def __sample_mini_batch__(self):
        return random.sample(self.replay.main_memory, self.replay.num_batch)

    def __update_target_models__(self):
        self.target_model.set_weights(self.eval_model.get_weights())

# %%
import gym
class Environment:
    
    def __init__(self):
        self.game = gym.make("MountainCar-v0")
        self.agent = DeepQAgent(1, 10000, 2000, 
                                10, 1, 0.05, 0.9995, 0.95)
        
    def train(self, num_ep: int):
        for i in range(1 , num_ep):
            print(f"Episodes {i}")
            state = self.game.reset()
            while True:
                # self.game.render()
                action = self.agent.pick_action(state)
                state_next, reward, terminal, info = self.game.step(action)
                self.agent.store_memory(state, action, reward, state_next, terminal)
                state = state_next
                if terminal:
                    break
                
            self.agent.learn()
            print(f"Epsilon: {self.agent.epsilon}")
            print(f"Reward: {reward}")
                
    def play(self):
        while True:
            state = self.game.reset()
            while True:
                self.game.render()
                action = self.agent.pick_action(state, 0)
                state, _, terminal, _ = self.game.step(action)
                if terminal:
                    break

# %%
environment = Environment()

# %%
environment.train(20000)
# Out:
# Episodes 1
# Epsilon: 1
# Reward: -1.0
# Episodes 2
# Epsilon: 1
# Reward: -1.0
# Episodes 3
# Epsilon: 1
# Reward: -1.0
# Episodes 4
# Epsilon: 1
# Reward: -1.0
# Episodes 5
# Epsilon: 1
# Reward: -1.0
# Episodes 6
# Epsilon: 1
# Reward: -1.0
# Episodes 7
# Epsilon: 1
# Reward: -1.0
# Episodes 8
# Epsilon: 1
# Reward: -1.0
# Episodes 9
# Epsilon: 1
# Reward: -1.0
# Episodes 10
# Epoch 1/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0457 - mse: 0.0457
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0061 - mse: 0.0061
# Epoch 3/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.0046 - mse: 0.0046
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 3.1535e-04 - mse: 3.1535e-04
# Epoch 7/10
# 63/63 [==============================] - 0s 2ms/step - loss: 8.7635e-06 - mse: 8.7635e-06
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 5.6333e-07 - mse: 5.6333e-07
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 4.7426e-07 - mse: 4.7426e-07
# Epoch 10/10
# 63/63 [==============================] - 0s 887us/step - loss: 4.2831e-07 - mse: 4.2831e-07
# Epsilon: 0.9995
# Reward: -1.0
# Episodes 11
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0270 - mse: 0.0270
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 5/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.0016 - mse: 0.0016
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 8/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.0016 - mse: 0.0016
# Epoch 9/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0016 - mse: 0.0016
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0016 - mse: 0.0016
# Epsilon: 0.9990002500000001
# Reward: -1.0
# Episodes 12
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0282 - mse: 0.0282
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0069 - mse: 0.0069
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0064 - mse: 0.0064
# Epoch 4/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0065 - mse: 0.0065
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0064 - mse: 0.0064
# Epoch 6/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.0066 - mse: 0.0066
# Epoch 7/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0065 - mse: 0.0065
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0065 - mse: 0.0065
# Epoch 9/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.0064 - mse: 0.0064
# Epoch 10/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.0065 - mse: 0.0065
# Epsilon: 0.9985007498750001
# Reward: -1.0
# Episodes 13
# Epoch 1/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.0337 - mse: 0.0337
# Epoch 2/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.0125 - mse: 0.0125
# Epoch 3/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.0129 - mse: 0.0129
# Epoch 4/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.0126 - mse: 0.0126
# Epoch 5/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.0129 - mse: 0.0129
# Epoch 6/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.0128 - mse: 0.0128
# Epoch 7/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.0125 - mse: 0.0125
# Epoch 8/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.0131 - mse: 0.0131
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0131 - mse: 0.0131
# Epoch 10/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.0127 - mse: 0.0127
# Epsilon: 0.9980014995000627
# Reward: -1.0
# Episodes 14
# Epoch 1/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.0414 - mse: 0.0414
# Epoch 2/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.0207 - mse: 0.0207
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0201 - mse: 0.0201
# Epoch 4/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.0210 - mse: 0.0210
# Epoch 5/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.0214 - mse: 0.0214
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0209 - mse: 0.0209
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0202 - mse: 0.0202
# Epoch 8/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.0202 - mse: 0.0202
# Epoch 9/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0204 - mse: 0.0204
# Epoch 10/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.0201 - mse: 0.0201
# Epsilon: 0.9975024987503127
# Reward: -1.0
# Episodes 15
# Epoch 1/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.0560 - mse: 0.0560
# Epoch 2/10
# 63/63 [==============================] - 0s 918us/step - loss: 0.0423 - mse: 0.0423
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0408 - mse: 0.0408
# Epoch 4/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.0402 - mse: 0.0402
# Epoch 5/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.0407 - mse: 0.0407
# Epoch 6/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0400 - mse: 0.0400
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0412 - mse: 0.0412
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0401 - mse: 0.0401
# Epoch 9/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.0411 - mse: 0.0411
# Epoch 10/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0425 - mse: 0.0425
# Epsilon: 0.9970037475009376
# Reward: -1.0
# Episodes 16
# Epoch 1/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.0589 - mse: 0.0589
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0442 - mse: 0.0442
# Epoch 3/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0446 - mse: 0.0446
# Epoch 4/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.0454 - mse: 0.0454
# Epoch 5/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.0434 - mse: 0.0434
# Epoch 6/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.0439 - mse: 0.0439
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0444 - mse: 0.0444
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0441 - mse: 0.0441
# Epoch 9/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.0442 - mse: 0.0442
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0433 - mse: 0.0433
# Epsilon: 0.9965052456271871
# Reward: -1.0
# Episodes 17
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0647 - mse: 0.0647
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0554 - mse: 0.0554
# Epoch 3/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0524 - mse: 0.0524
# Epoch 4/10
# 63/63 [==============================] - 0s 977us/step - loss: 0.0534 - mse: 0.0534
# Epoch 5/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0537 - mse: 0.0537
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0534 - mse: 0.0534
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0536 - mse: 0.0536
# Epoch 8/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.0530 - mse: 0.0530
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0529 - mse: 0.0529
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0550 - mse: 0.0550
# Epsilon: 0.9960069930043736
# Reward: -1.0
# Episodes 18
# Epoch 1/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0435 - mse: 0.0435
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0325 - mse: 0.0325
# Epoch 3/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.0306 - mse: 0.0306
# Epoch 4/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.0334 - mse: 0.0334
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0306 - mse: 0.0306
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0312 - mse: 0.0312
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0322 - mse: 0.0322
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0335 - mse: 0.0335
# Epoch 9/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0306 - mse: 0.0306
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0312 - mse: 0.0312
# Epsilon: 0.9955089895078715
# Reward: -1.0
# Episodes 19
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0710 - mse: 0.0710
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0601 - mse: 0.0601
# Epoch 3/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.0616 - mse: 0.0616
# Epoch 4/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.0606 - mse: 0.0606
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0639 - mse: 0.0639
# Epoch 6/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.0633 - mse: 0.0633
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0615 - mse: 0.0615
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0623 - mse: 0.0623
# Epoch 9/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0603 - mse: 0.0603
# Epoch 10/10
# 63/63 [==============================] - 0s 983us/step - loss: 0.0633 - mse: 0.0633
# Epsilon: 0.9950112350131176
# Reward: -1.0
# Episodes 20
# Epoch 1/10
# 63/63 [==============================] - 0s 923us/step - loss: 0.1037 - mse: 0.1037
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0927 - mse: 0.0927
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.0926 - mse: 0.0926
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0948 - mse: 0.0948
# Epoch 5/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.0904 - mse: 0.0904
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0910 - mse: 0.0910
# Epoch 7/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.0905 - mse: 0.0905
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0922 - mse: 0.0922
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0921 - mse: 0.0921
# Epoch 10/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.0925 - mse: 0.0925
# Epsilon: 0.9945137293956111
# Reward: -1.0
# Episodes 21
# Epoch 1/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1330 - mse: 0.1330
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1329 - mse: 0.1329
# Epoch 3/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1306 - mse: 0.1306
# Epoch 4/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.1304 - mse: 0.1304
# Epoch 5/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.1324 - mse: 0.1324
# Epoch 6/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.1286 - mse: 0.1286
# Epoch 7/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1287 - mse: 0.1287
# Epoch 8/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1288 - mse: 0.1288
# Epoch 9/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1347 - mse: 0.1347
# Epoch 10/10
# 63/63 [==============================] - 0s 921us/step - loss: 0.1286 - mse: 0.1286
# Epsilon: 0.9940164725309134
# Reward: -1.0
# Episodes 22
# Epoch 1/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.0938 - mse: 0.0938
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0869 - mse: 0.0869
# Epoch 3/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.0885 - mse: 0.0885
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0868 - mse: 0.0868
# Epoch 5/10
# 63/63 [==============================] - 0s 989us/step - loss: 0.0865 - mse: 0.0865
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0873 - mse: 0.0873
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0856 - mse: 0.0856
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0864 - mse: 0.0864
# Epoch 9/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.0875 - mse: 0.0875
# Epoch 10/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.0867 - mse: 0.0867
# Epsilon: 0.993519464294648
# Reward: -1.0
# Episodes 23
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1069 - mse: 0.1069
# Epoch 2/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.1017 - mse: 0.1017
# Epoch 3/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.1061 - mse: 0.1061
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1009 - mse: 0.1009
# Epoch 5/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1002 - mse: 0.1002
# Epoch 6/10
# 63/63 [==============================] - 0s 920us/step - loss: 0.0992 - mse: 0.0992
# Epoch 7/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1009 - mse: 0.1009
# Epoch 8/10
# 63/63 [==============================] - 0s 927us/step - loss: 0.1022 - mse: 0.1022
# Epoch 9/10
# 63/63 [==============================] - 0s 855us/step - loss: 0.1001 - mse: 0.1001
# Epoch 10/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.1036 - mse: 0.1036
# Epsilon: 0.9930227045625007
# Reward: -1.0
# Episodes 24
# Epoch 1/10
# 63/63 [==============================] - 0s 823us/step - loss: 0.1285 - mse: 0.1285
# Epoch 2/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1163 - mse: 0.1163
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1169 - mse: 0.1169
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1187 - mse: 0.1187
# Epoch 5/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.1186 - mse: 0.1186
# Epoch 6/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.1184 - mse: 0.1184
# Epoch 7/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.1159 - mse: 0.1159
# Epoch 8/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.1156 - mse: 0.1156
# Epoch 9/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.1157 - mse: 0.1157
# Epoch 10/10
# 63/63 [==============================] - 0s 855us/step - loss: 0.1158 - mse: 0.1158
# Epsilon: 0.9925261932102195
# Reward: -1.0
# Episodes 25
# Epoch 1/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1166 - mse: 0.1166
# Epoch 2/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1117 - mse: 0.1117
# Epoch 3/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1111 - mse: 0.1111
# Epoch 4/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.1118 - mse: 0.1118
# Epoch 5/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.1131 - mse: 0.1131
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1149 - mse: 0.1149
# Epoch 7/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.1135 - mse: 0.1135
# Epoch 8/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.1131 - mse: 0.1131
# Epoch 9/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1122 - mse: 0.1122
# Epoch 10/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.1154 - mse: 0.1154
# Epsilon: 0.9920299301136144
# Reward: -1.0
# Episodes 26
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1525 - mse: 0.1525
# Epoch 2/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1545 - mse: 0.1545
# Epoch 3/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.1561 - mse: 0.1561
# Epoch 4/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.1501 - mse: 0.1501
# Epoch 5/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1563 - mse: 0.1563
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1523 - mse: 0.1523
# Epoch 7/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1524 - mse: 0.1524
# Epoch 8/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.1517 - mse: 0.1517
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1533 - mse: 0.1533
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1492 - mse: 0.1492
# Epsilon: 0.9915339151485576
# Reward: -1.0
# Episodes 27
# Epoch 1/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2244 - mse: 0.2244
# Epoch 2/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2180 - mse: 0.2180
# Epoch 3/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2148 - mse: 0.2148
# Epoch 4/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.2178 - mse: 0.2178
# Epoch 5/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2134 - mse: 0.2134
# Epoch 6/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.2198 - mse: 0.2198
# Epoch 7/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2159 - mse: 0.2159
# Epoch 8/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2189 - mse: 0.2189
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2145 - mse: 0.2145
# Epoch 10/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2136 - mse: 0.2136
# Epsilon: 0.9910381481909833
# Reward: -1.0
# Episodes 28
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2421 - mse: 0.2421
# Epoch 2/10
# 63/63 [==============================] - 0s 955us/step - loss: 0.2427 - mse: 0.2427
# Epoch 3/10
# 63/63 [==============================] - 0s 982us/step - loss: 0.2382 - mse: 0.2382
# Epoch 4/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2373 - mse: 0.2373
# Epoch 5/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.2489 - mse: 0.2489
# Epoch 6/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2533 - mse: 0.2533
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2490 - mse: 0.2490
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2394 - mse: 0.2394
# Epoch 9/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.2426 - mse: 0.2426
# Epoch 10/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2402 - mse: 0.2402
# Epsilon: 0.990542629116888
# Reward: -1.0
# Episodes 29
# Epoch 1/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1869 - mse: 0.1869
# Epoch 2/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.1836 - mse: 0.1836
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1855 - mse: 0.1855
# Epoch 4/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1857 - mse: 0.1857
# Epoch 5/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.1914 - mse: 0.1914
# Epoch 6/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1832 - mse: 0.1832
# Epoch 7/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.1948 - mse: 0.1948
# Epoch 8/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.1927 - mse: 0.1927
# Epoch 9/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1873 - mse: 0.1873
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1932 - mse: 0.1932
# Epsilon: 0.9900473578023296
# Reward: -1.0
# Episodes 30
# Epoch 1/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2446 - mse: 0.2446
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2489 - mse: 0.2489
# Epoch 3/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2382 - mse: 0.2382
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2463 - mse: 0.2463
# Epoch 5/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2432 - mse: 0.2432
# Epoch 6/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2482 - mse: 0.2482
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2410 - mse: 0.2410
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2426 - mse: 0.2426
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2459 - mse: 0.2459
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2407 - mse: 0.2407
# Epsilon: 0.9895523341234285
# Reward: -1.0
# Episodes 31
# Epoch 1/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1882 - mse: 0.1882
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1935 - mse: 0.1935
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1873 - mse: 0.1873
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1847 - mse: 0.1847
# Epoch 5/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1825 - mse: 0.1825
# Epoch 6/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.1817 - mse: 0.1817
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1858 - mse: 0.1858
# Epoch 8/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.1903 - mse: 0.1903
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1867 - mse: 0.1867
# Epoch 10/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1863 - mse: 0.1863
# Epsilon: 0.9890575579563669
# Reward: -1.0
# Episodes 32
# Epoch 1/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2300 - mse: 0.2300
# Epoch 2/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2167 - mse: 0.2167
# Epoch 3/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2153 - mse: 0.2153
# Epoch 4/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2160 - mse: 0.2160
# Epoch 5/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.2202 - mse: 0.2202
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2169 - mse: 0.2169
# Epoch 7/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.2184 - mse: 0.2184
# Epoch 8/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2285 - mse: 0.2285
# Epoch 9/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2138 - mse: 0.2138
# Epoch 10/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.2134 - mse: 0.2134
# Epsilon: 0.9885630291773887
# Reward: -1.0
# Episodes 33
# Epoch 1/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2326 - mse: 0.2326
# Epoch 2/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2305 - mse: 0.2305
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2302 - mse: 0.2302
# Epoch 4/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.2296 - mse: 0.2296
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2339 - mse: 0.2339
# Epoch 6/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2263 - mse: 0.2263
# Epoch 7/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2284 - mse: 0.2284
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2215 - mse: 0.2215
# Epoch 9/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.2219 - mse: 0.2219
# Epoch 10/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2276 - mse: 0.2276
# Epsilon: 0.9880687476628001
# Reward: -1.0
# Episodes 34
# Epoch 1/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2300 - mse: 0.2300
# Epoch 2/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2350 - mse: 0.2350
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2287 - mse: 0.2287
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2376 - mse: 0.2376
# Epoch 5/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2340 - mse: 0.2340
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2257 - mse: 0.2257
# Epoch 7/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2318 - mse: 0.2318
# Epoch 8/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2282 - mse: 0.2282
# Epoch 9/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.2281 - mse: 0.2281
# Epoch 10/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2341 - mse: 0.2341
# Epsilon: 0.9875747132889687
# Reward: -1.0
# Episodes 35
# Epoch 1/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2807 - mse: 0.2807
# Epoch 2/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2702 - mse: 0.2702
# Epoch 3/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2677 - mse: 0.2677
# Epoch 4/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2767 - mse: 0.2767
# Epoch 5/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2733 - mse: 0.2733
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2686 - mse: 0.2686
# Epoch 7/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2768 - mse: 0.2768
# Epoch 8/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2704 - mse: 0.2704
# Epoch 9/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2694 - mse: 0.2694
# Epoch 10/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2747 - mse: 0.2747
# Epsilon: 0.9870809259323243
# Reward: -1.0
# Episodes 36
# Epoch 1/10
# 63/63 [==============================] - 0s 855us/step - loss: 0.2115 - mse: 0.2115
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2144 - mse: 0.2144
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2072 - mse: 0.2072
# Epoch 4/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2093 - mse: 0.2093
# Epoch 5/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2113 - mse: 0.2113
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2164 - mse: 0.2164
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2097 - mse: 0.2097
# Epoch 8/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2123 - mse: 0.2123
# Epoch 9/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2141 - mse: 0.2141
# Epoch 10/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.2091 - mse: 0.2091
# Epsilon: 0.9865873854693582
# Reward: -1.0
# Episodes 37
# Epoch 1/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.2516 - mse: 0.2516
# Epoch 2/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2521 - mse: 0.2521
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2620 - mse: 0.2620
# Epoch 4/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.2538 - mse: 0.2538
# Epoch 5/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2505 - mse: 0.2505
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2482 - mse: 0.2482
# Epoch 7/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.2503 - mse: 0.2503
# Epoch 8/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2459 - mse: 0.2459
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2489 - mse: 0.2489
# Epoch 10/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.2466 - mse: 0.2466
# Epsilon: 0.9860940917766235
# Reward: -1.0
# Episodes 38
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2443 - mse: 0.2443
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2461 - mse: 0.2461
# Epoch 3/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.2435 - mse: 0.2435
# Epoch 4/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2474 - mse: 0.2474
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2446 - mse: 0.2446
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2436 - mse: 0.2436
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2452 - mse: 0.2452
# Epoch 8/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2385 - mse: 0.2385
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2434 - mse: 0.2434
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2396 - mse: 0.2396
# Epsilon: 0.9856010447307353
# Reward: -1.0
# Episodes 39
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1881 - mse: 0.1881
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1868 - mse: 0.1868
# Epoch 3/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1857 - mse: 0.1857
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1828 - mse: 0.1828
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1823 - mse: 0.1823
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1823 - mse: 0.1823
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1822 - mse: 0.1822
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1891 - mse: 0.1891
# Epoch 9/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1806 - mse: 0.1806
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1826 - mse: 0.1826
# Epsilon: 0.98510824420837
# Reward: -1.0
# Episodes 40
# Epoch 1/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1185 - mse: 0.1185
# Epoch 2/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1158 - mse: 0.1158
# Epoch 3/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.1157 - mse: 0.1157
# Epoch 4/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1186 - mse: 0.1186
# Epoch 5/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1180 - mse: 0.1180
# Epoch 6/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.1195 - mse: 0.1195
# Epoch 7/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.1159 - mse: 0.1159
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1157 - mse: 0.1157
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1159 - mse: 0.1159
# Epoch 10/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1147 - mse: 0.1147
# Epsilon: 0.9846156900862658
# Reward: -1.0
# Episodes 41
# Epoch 1/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.3546 - mse: 0.3546
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3679 - mse: 0.3679
# Epoch 3/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3548 - mse: 0.3548
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3715 - mse: 0.3715
# Epoch 5/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.3592 - mse: 0.3592
# Epoch 6/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.3599 - mse: 0.3599
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3594 - mse: 0.3594
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3561 - mse: 0.3561
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3606 - mse: 0.3606
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3593 - mse: 0.3593
# Epsilon: 0.9841233822412228
# Reward: -1.0
# Episodes 42
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3480 - mse: 0.3480
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3441 - mse: 0.3441
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3578 - mse: 0.3578
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3571 - mse: 0.3571
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3469 - mse: 0.3469
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3532 - mse: 0.3532
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3443 - mse: 0.3443
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3465 - mse: 0.3465
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3457 - mse: 0.3457
# Epoch 10/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.3432 - mse: 0.3432
# Epsilon: 0.9836313205501022
# Reward: -1.0
# Episodes 43
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3656 - mse: 0.3656
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3752 - mse: 0.3752
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3733 - mse: 0.3733
# Epoch 4/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.3679 - mse: 0.3679
# Epoch 5/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3691 - mse: 0.3691
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3719 - mse: 0.3719
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3708 - mse: 0.3708
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3710 - mse: 0.3710
# Epoch 9/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3731 - mse: 0.3731
# Epoch 10/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.3747 - mse: 0.3747
# Epsilon: 0.9831395048898272
# Reward: -1.0
# Episodes 44
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2923 - mse: 0.2923
# Epoch 2/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2959 - mse: 0.2959
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2926 - mse: 0.2926
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2974 - mse: 0.2974
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2954 - mse: 0.2954
# Epoch 6/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.3069 - mse: 0.3069
# Epoch 7/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2945 - mse: 0.2945
# Epoch 8/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2970 - mse: 0.2970
# Epoch 9/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2975 - mse: 0.2975
# Epoch 10/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2990 - mse: 0.2990
# Epsilon: 0.9826479351373822
# Reward: -1.0
# Episodes 45
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2451 - mse: 0.2451
# Epoch 2/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.2462 - mse: 0.2462
# Epoch 3/10
# 63/63 [==============================] - 0s 908us/step - loss: 0.2511 - mse: 0.2511
# Epoch 4/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2442 - mse: 0.2442
# Epoch 5/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.2424 - mse: 0.2424
# Epoch 6/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2425 - mse: 0.2425
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.2414 - mse: 0.2414
# Epoch 8/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2522 - mse: 0.2522
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2417 - mse: 0.2417
# Epoch 10/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.2485 - mse: 0.2485
# Epsilon: 0.9821566111698136
# Reward: -1.0
# Episodes 46
# Epoch 1/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.5484 - mse: 0.5484
# Epoch 2/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.5359 - mse: 0.5359
# Epoch 3/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.5528 - mse: 0.5528
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5341 - mse: 0.5341
# Epoch 5/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.5363 - mse: 0.5363
# Epoch 6/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.5417 - mse: 0.5417
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.5429 - mse: 0.5429
# Epoch 8/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.5446 - mse: 0.5446
# Epoch 9/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.5408 - mse: 0.5408
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5374 - mse: 0.5374
# Epsilon: 0.9816655328642288
# Reward: -1.0
# Episodes 47
# Epoch 1/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2304 - mse: 0.2304
# Epoch 2/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2342 - mse: 0.2342
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2299 - mse: 0.2299
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2299 - mse: 0.2299
# Epoch 5/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2339 - mse: 0.2339
# Epoch 6/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.2363 - mse: 0.2363
# Epoch 7/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.2282 - mse: 0.2282
# Epoch 8/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.2328 - mse: 0.2328
# Epoch 9/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.2319 - mse: 0.2319
# Epoch 10/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.2323 - mse: 0.2323
# Epsilon: 0.9811747000977967
# Reward: -1.0
# Episodes 48
# Epoch 1/10
# 63/63 [==============================] - 0s 855us/step - loss: 0.3422 - mse: 0.3422
# Epoch 2/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.3469 - mse: 0.3469
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3454 - mse: 0.3454
# Epoch 4/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.3396 - mse: 0.3396
# Epoch 5/10
# 63/63 [==============================] - 0s 855us/step - loss: 0.3462 - mse: 0.3462
# Epoch 6/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.3455 - mse: 0.3455
# Epoch 7/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3433 - mse: 0.3433
# Epoch 8/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.3378 - mse: 0.3378
# Epoch 9/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.3426 - mse: 0.3426
# Epoch 10/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.3503 - mse: 0.3503
# Epsilon: 0.9806841127477479
# Reward: -1.0
# Episodes 49
# Epoch 1/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.3468 - mse: 0.3468
# Epoch 2/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3505 - mse: 0.3505
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3473 - mse: 0.3473
# Epoch 4/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.3500 - mse: 0.3500
# Epoch 5/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3657 - mse: 0.3657
# Epoch 6/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.3451 - mse: 0.3451
# Epoch 7/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.3450 - mse: 0.3450
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3499 - mse: 0.3499
# Epoch 9/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.3542 - mse: 0.3542
# Epoch 10/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.3533 - mse: 0.3533
# Epsilon: 0.9801937706913741
# Reward: -1.0
# Episodes 50
# Epoch 1/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.4518 - mse: 0.4518
# Epoch 2/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.4482 - mse: 0.4482
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.4562 - mse: 0.4562
# Epoch 4/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.4502 - mse: 0.4502
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4537 - mse: 0.4537
# Epoch 6/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.4481 - mse: 0.4481
# Epoch 7/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.4460 - mse: 0.4460
# Epoch 8/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.4538 - mse: 0.4538
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4470 - mse: 0.4470
# Epoch 10/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.4586 - mse: 0.4586
# Epsilon: 0.9797036738060285
# Reward: -1.0
# Episodes 51
# Epoch 1/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.1961 - mse: 0.1961
# Epoch 2/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.1927 - mse: 0.1927
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1980 - mse: 0.1980
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1909 - mse: 0.1909
# Epoch 5/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1891 - mse: 0.1891
# Epoch 6/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1902 - mse: 0.1902
# Epoch 7/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.1918 - mse: 0.1918
# Epoch 8/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.1909 - mse: 0.1909
# Epoch 9/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.1887 - mse: 0.1887
# Epoch 10/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.1927 - mse: 0.1927
# Epsilon: 0.9792138219691255
# Reward: -1.0
# Episodes 52
# Epoch 1/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.3094 - mse: 0.3094
# Epoch 2/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.3103 - mse: 0.3103
# Epoch 3/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3093 - mse: 0.3093
# Epoch 4/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.3084 - mse: 0.3084
# Epoch 5/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.3138 - mse: 0.3138
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3044 - mse: 0.3044
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3158 - mse: 0.3158
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3143 - mse: 0.3143
# Epoch 9/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.3111 - mse: 0.3111
# Epoch 10/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.3074 - mse: 0.3074
# Epsilon: 0.978724215058141
# Reward: -1.0
# Episodes 53
# Epoch 1/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.5015 - mse: 0.5015
# Epoch 2/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.4960 - mse: 0.4960
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5047 - mse: 0.5047
# Epoch 4/10
# 63/63 [==============================] - 0s 887us/step - loss: 0.4987 - mse: 0.4987
# Epoch 5/10
# 63/63 [==============================] - 0s 901us/step - loss: 0.4914 - mse: 0.4914
# Epoch 6/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.4972 - mse: 0.4972
# Epoch 7/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.4975 - mse: 0.4975
# Epoch 8/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.4966 - mse: 0.4966
# Epoch 9/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.4916 - mse: 0.4916
# Epoch 10/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.5016 - mse: 0.5016
# Epsilon: 0.978234852950612
# Reward: -1.0
# Episodes 54
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3438 - mse: 0.3438
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3363 - mse: 0.3363
# Epoch 3/10
# 63/63 [==============================] - 0s 871us/step - loss: 0.3368 - mse: 0.3368
# Epoch 4/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.3363 - mse: 0.3363
# Epoch 5/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.3333 - mse: 0.3333
# Epoch 6/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.3424 - mse: 0.3424
# Epoch 7/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.3404 - mse: 0.3404
# Epoch 8/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.3395 - mse: 0.3395
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3326 - mse: 0.3326
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3342 - mse: 0.3342
# Epsilon: 0.9777457355241367
# Reward: -1.0
# Episodes 55
# Epoch 1/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4129 - mse: 0.4129
# Epoch 2/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.4046 - mse: 0.4046
# Epoch 3/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.4095 - mse: 0.4095
# Epoch 4/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.4032 - mse: 0.4032
# Epoch 5/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.4033 - mse: 0.4033
# Epoch 6/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.4036 - mse: 0.4036
# Epoch 7/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.4090 - mse: 0.4090
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4087 - mse: 0.4087
# Epoch 9/10
# 63/63 [==============================] - 0s 919us/step - loss: 0.4033 - mse: 0.4033
# Epoch 10/10
# 63/63 [==============================] - 0s 903us/step - loss: 0.4030 - mse: 0.4030
# Epsilon: 0.9772568626563747
# Reward: -1.0
# Episodes 56
# Epoch 1/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3270 - mse: 0.3270
# Epoch 2/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3281 - mse: 0.3281
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3288 - mse: 0.3288
# Epoch 4/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3284 - mse: 0.3284
# Epoch 5/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3315 - mse: 0.3315
# Epoch 6/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.3295 - mse: 0.3295
# Epoch 7/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.3321 - mse: 0.3321
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3275 - mse: 0.3275
# Epoch 9/10
# 63/63 [==============================] - 0s 952us/step - loss: 0.3300 - mse: 0.3300
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3377 - mse: 0.3377
# Epsilon: 0.9767682342250465
# Reward: -1.0
# Episodes 57
# Epoch 1/10
# 63/63 [==============================] - 0s 935us/step - loss: 0.3237 - mse: 0.3237
# Epoch 2/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.3256 - mse: 0.3256
# Epoch 3/10
# 63/63 [==============================] - 0s 1000us/step - loss: 0.3267 - mse: 0.3267
# Epoch 4/10
# 63/63 [==============================] - 0s 984us/step - loss: 0.3288 - mse: 0.3288
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3267 - mse: 0.3267
# Epoch 6/10
# 63/63 [==============================] - 0s 968us/step - loss: 0.3329 - mse: 0.3329
# Epoch 7/10
# 63/63 [==============================] - 0s 936us/step - loss: 0.3270 - mse: 0.3270
# ...
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1943'>1944</a>   except ValueError:
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1944'>1945</a>     warnings.warn(
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1945'>1946</a>         'Using Model.predict with MultiWorkerMirroredStrategy or '
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1946'>1947</a>         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1947'>1948</a>         'result. Consider setting it to AutoShardPolicy.DATA.',
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1948'>1949</a>         stacklevel=2)
# -> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1950'>1951</a> data_handler = data_adapter.get_data_handler(
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1951'>1952</a>     x=x,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1952'>1953</a>     batch_size=batch_size,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1953'>1954</a>     steps_per_epoch=steps,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1954'>1955</a>     initial_epoch=0,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1955'>1956</a>     epochs=1,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1956'>1957</a>     max_queue_size=max_queue_size,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1957'>1958</a>     workers=workers,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1958'>1959</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1959'>1960</a>     model=self,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1960'>1961</a>     steps_per_execution=self._steps_per_execution)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1962'>1963</a> # Container that configures and calls `tf.keras.Callback`s.
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/training.py?line=1963'>1964</a> if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File D:\@Programming\@On Going\Data\DeepQLearning\venv\lib\site-packages\keras\engine\data_adapter.py:1399, in get_data_handler(*args, **kwargs)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1396'>1397</a> if getattr(kwargs["model"], "_cluster_coordinator", None):
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1397'>1398</a>   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1398'>1399</a> return DataHandler(*args, **kwargs)
#
# File D:\@Programming\@On Going\Data\DeepQLearning\venv\lib\site-packages\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1145'>1146</a>   self._steps_per_execution = steps_per_execution
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1147'>1148</a> adapter_cls = select_data_adapter(x, y)
# -> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1148'>1149</a> self._adapter = adapter_cls(
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1149'>1150</a>     x,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1150'>1151</a>     y,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1151'>1152</a>     batch_size=batch_size,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1152'>1153</a>     steps=steps_per_epoch,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1153'>1154</a>     epochs=epochs - initial_epoch,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1154'>1155</a>     sample_weights=sample_weight,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1155'>1156</a>     shuffle=shuffle,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1156'>1157</a>     max_queue_size=max_queue_size,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1157'>1158</a>     workers=workers,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1158'>1159</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1159'>1160</a>     distribution_strategy=tf.distribute.get_strategy(),
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1160'>1161</a>     model=model)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1162'>1163</a> strategy = tf.distribute.get_strategy()
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=1164'>1165</a> self._current_step = 0
#
# File D:\@Programming\@On Going\Data\DeepQLearning\venv\lib\site-packages\keras\engine\data_adapter.py:664, in ListsOfScalarsDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, shuffle, **kwargs)
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=659'>660</a>   sample_weights = np.asarray(sample_weights)
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=660'>661</a> sample_weight_modes = broadcast_sample_weight_modes(
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=661'>662</a>     sample_weights, sample_weight_modes)
# --> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=663'>664</a> self._internal_adapter = TensorLikeDataAdapter(
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=664'>665</a>     x,
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=665'>666</a>     y=y,
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=666'>667</a>     sample_weights=sample_weights,
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=667'>668</a>     sample_weight_modes=sample_weight_modes,
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=668'>669</a>     batch_size=batch_size,
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=669'>670</a>     shuffle=shuffle,
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=670'>671</a>     **kwargs)
#
# File D:\@Programming\@On Going\Data\DeepQLearning\venv\lib\site-packages\keras\engine\data_adapter.py:326, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=322'>323</a>     flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=323'>324</a>   return flat_dataset
# --> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=325'>326</a> indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=327'>328</a> dataset = self.slice_inputs(indices_dataset, inputs)
#     <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/keras/engine/data_adapter.py?line=329'>330</a> if shuffle == "batch":
#
# File D:\@Programming\@On Going\Data\DeepQLearning\venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2060, in DatasetV2.flat_map(self, map_func, name)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2025'>2026</a> def flat_map(self, map_func, name=None):
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2026'>2027</a>   """Maps `map_func` across this dataset and flattens the result.
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2027'>2028</a>
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2028'>2029</a>   The type signature is:
#    (...)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2057'>2058</a>     Dataset: A `Dataset`.
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2058'>2059</a>   """
# -> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2059'>2060</a>   return FlatMapDataset(self, map_func, name=name)
#
# File D:\@Programming\@On Going\Data\DeepQLearning\venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5289, in FlatMapDataset.__init__(self, input_dataset, map_func, name)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5286'>5287</a> if name:
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5287'>5288</a>   self._metadata.name = _validate_and_encode(name)
# -> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5288'>5289</a> variant_tensor = gen_dataset_ops.flat_map_dataset(
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5289'>5290</a>     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5290'>5291</a>     self._map_func.function.captured_inputs,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5291'>5292</a>     f=self._map_func.function,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5292'>5293</a>     **self._common_args)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5293'>5294</a> super(FlatMapDataset, self).__init__(input_dataset, variant_tensor)
#
# File D:\@Programming\@On Going\Data\DeepQLearning\venv\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:2262, in flat_map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, metadata, name)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2259'>2260</a> if tld.is_eager:
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2260'>2261</a>   try:
# -> <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2261'>2262</a>     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2262'>2263</a>       _ctx, "FlatMapDataset", name, input_dataset, other_arguments, "f", f,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2263'>2264</a>       "output_types", output_types, "output_shapes", output_shapes,
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2264'>2265</a>       "metadata", metadata)
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2265'>2266</a>     return _result
#    <a href='file:///d%3A/%40Programming/%40On%20Going/Data/DeepQLearning/venv/lib/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2266'>2267</a>   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
en
